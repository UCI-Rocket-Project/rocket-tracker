# %%
from flight_model import test_flight

test_flight.all_info()
# Out:
# Initial Conditions
#
# Position - x: 0.00 m | y: 0.00 m | z: 596.00 m
# Velocity - Vx: 0.00 m/s | Vy: 0.00 m/s | Vz: 0.00 m/s
# Attitude - e0: 1.000 | e1: 0.000 | e2: 0.000 | e3: 0.000
# Euler Angles - Spin φ : 180.00° | Nutation θ: -0.00° | Precession ψ: -180.00°
# Angular Velocity - ω1: 0.00 rad/s | ω2: 0.00 rad/s| ω3: 0.00 rad/s
#
#
# Surface Wind Conditions
#
# Frontal Surface Wind Speed: 3.39 m/s
# Lateral Surface Wind Speed: -0.16 m/s
#
#
# Launch Rail
#
# Launch Rail Length: 18.288  m
# Launch Rail Inclination: 90.00°
# Launch Rail Heading: 0.00°
#
#
# Rail Departure State
#
# Rail Departure Time: 2.193 s
# Rail Departure Velocity: 21.633 m/s
# Rail Departure Static Margin: 3.116 c
# Rail Departure Angle of Attack: 8.965°
# Rail Departure Thrust-Weight Ratio: 2.979
# Rail Departure Reynolds Number: 4.246e+05
#
#
# Burn out State
#
# Burn out time: 13.833 s
# Altitude at burn out: 1745.474 m (AGL)
# Rocket velocity at burn out: 246.977 m/s
# ...
